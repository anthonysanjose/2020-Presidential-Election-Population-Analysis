# %%
import numpy as np
import pandas as pd 
import datetime as dt

# %%
df =pd.read_csv(r"C:\Users\president_counties.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                 state                county     candidate party  \
# 0           0              Delaware           Kent County     Joe Biden   DEM
# 1           4              Delaware     New Castle County     Joe Biden   DEM
# 2           8              Delaware         Sussex County  Donald Trump   REP
# 3          12  District of Columbia  District of Columbia     Joe Biden   DEM
# 4          19               Florida        Alachua County     Joe Biden   DEM
#
#    total_votes   won   fips state_code    male  female  median_age  \
# 0        44552  True  10001         DE   84271   90551        37.6
# 1       195034  True  10003         DE  268870  286263        38.1
# 2        71230  True  10005         DE  106429  113111        49.0
# 3        39041  True  11001        NaN  324881  359617        33.9
# 4        89704  True  12001         FL  127298  135850        31.3
#
#    population  female_percentage        lat       long color
# ...

# %%
df.describe().round(2).transpose()
# Out:
#                     count       mean        std     min       25%       50%  \
# Unnamed: 0         3045.0    9477.00    5366.48     0.0   4444.00   9933.00
# total_votes        3045.0   30956.48   97229.06    60.0   3782.00   8345.00
# fips               3045.0   30655.91   15025.41  1001.0  19021.00  29217.00
# male               3045.0   49720.48  162841.79    58.0   5489.00  12641.00
# female             3045.0   51230.16  168664.95    44.0   5462.00  12738.00
# median_age         3045.0      41.27       5.39    21.7     38.00     41.20
# population         3045.0  100950.65  331468.42   102.0  10948.00  25360.00
# female_percentage  3045.0      49.92       2.37    21.0     49.41     50.37
# lat                3045.0      38.15       4.86    19.6     34.57     38.18
# long               3045.0     -92.20      11.44  -159.6    -98.21    -90.54
#
#                         75%          max
# Unnamed: 0         14092.00     19577.00
# total_votes        21225.00   3028885.00
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# state                 object
# county                object
# candidate             object
# party                 object
# total_votes            int64
# won                     bool
# fips                   int64
# state_code            object
# male                   int64
# female                 int64
# median_age           float64
# population             int64
# female_percentage    float64
# lat                  float64
# long                 float64
# color                 object
# dtype: object

# %%
df.sort_values('population')
# Out:
#       Unnamed: 0       state              county     candidate party  \
# 2311       14210       Texas       Loving County  Donald Trump   REP
# 2295       14141       Texas         King County  Donald Trump   REP
# 1309        8799    Nebraska       Arthur County  Donald Trump   REP
# 1285        8704     Montana    Petroleum County  Donald Trump   REP
# 1365        9019    Nebraska    McPherson County  Donald Trump   REP
# ...          ...         ...                 ...           ...   ...
# 2937       17948  California    San Diego County     Joe Biden   DEM
# 3043       19573     Arizona     Maricopa County     Joe Biden   DEM
# 2261       14000       Texas       Harris County     Joe Biden   DEM
# 293         1632    Illinois         Cook County     Joe Biden   DEM
# 2917       17826  California  Los Angeles County     Joe Biden   DEM
#
#       total_votes   won   fips state_code     male   female  median_age  \
# ...

# %%
df.sort_values('population', ascending = False)
# Out:
#       Unnamed: 0       state              county     candidate party  \
# 2917       17826  California  Los Angeles County     Joe Biden   DEM
# 293         1632    Illinois         Cook County     Joe Biden   DEM
# 2261       14000       Texas       Harris County     Joe Biden   DEM
# 3043       19573     Arizona     Maricopa County     Joe Biden   DEM
# 2937       17948  California    San Diego County     Joe Biden   DEM
# ...          ...         ...                 ...           ...   ...
# 1365        9019    Nebraska    McPherson County  Donald Trump   REP
# 1285        8704     Montana    Petroleum County  Donald Trump   REP
# 1309        8799    Nebraska       Arthur County  Donald Trump   REP
# 2295       14141       Texas         King County  Donald Trump   REP
# 2311       14210       Texas       Loving County  Donald Trump   REP
#
#       total_votes   won   fips state_code     male   female  median_age  \
# ...

# %%
df.sort_values(['population', 'candidate'], ascending = False)
# Out:
#       Unnamed: 0       state              county     candidate party  \
# 2917       17826  California  Los Angeles County     Joe Biden   DEM
# 293         1632    Illinois         Cook County     Joe Biden   DEM
# 2261       14000       Texas       Harris County     Joe Biden   DEM
# 3043       19573     Arizona     Maricopa County     Joe Biden   DEM
# 2937       17948  California    San Diego County     Joe Biden   DEM
# ...          ...         ...                 ...           ...   ...
# 1365        9019    Nebraska    McPherson County  Donald Trump   REP
# 1285        8704     Montana    Petroleum County  Donald Trump   REP
# 1309        8799    Nebraska       Arthur County  Donald Trump   REP
# 2295       14141       Texas         King County  Donald Trump   REP
# 2311       14210       Texas       Loving County  Donald Trump   REP
#
#       total_votes   won   fips state_code     male   female  median_age  \
# ...

# %%
df.sort_values(['candidate', 'population'], ascending = False)
# Out:
#       Unnamed: 0       state              county     candidate party  \
# 2917       17826  California  Los Angeles County     Joe Biden   DEM
# 293         1632    Illinois         Cook County     Joe Biden   DEM
# 2261       14000       Texas       Harris County     Joe Biden   DEM
# 3043       19573     Arizona     Maricopa County     Joe Biden   DEM
# 2937       17948  California    San Diego County     Joe Biden   DEM
# ...          ...         ...                 ...           ...   ...
# 1365        9019    Nebraska    McPherson County  Donald Trump   REP
# 1285        8704     Montana    Petroleum County  Donald Trump   REP
# 1309        8799    Nebraska       Arthur County  Donald Trump   REP
# 2295       14141       Texas         King County  Donald Trump   REP
# 2311       14210       Texas       Loving County  Donald Trump   REP
#
#       total_votes   won   fips state_code     male   female  median_age  \
# ...

# %%
df.sort_values(['candidate', 'population'], ascending = False).mean()
# Out:
# Unnamed: 0             9477.001314
# total_votes           30956.484401
# won                       1.000000
# fips                  30655.909360
# male                  49720.484729
# female                51230.161905
# median_age               41.266108
# population           100950.646634
# female_percentage        49.924573
# lat                      38.148000
# long                    -92.196232
# dtype: float64

# %%
#split dataframe 
grouped_dem = df.groupby(df.party) 
df_dem = grouped_dem.get_group("DEM") 
df_dem
# Out:
#       Unnamed: 0                 state                county  candidate party  \
# 0              0              Delaware           Kent County  Joe Biden   DEM
# 1              4              Delaware     New Castle County  Joe Biden   DEM
# 3             12  District of Columbia  District of Columbia  Joe Biden   DEM
# 4             19               Florida        Alachua County  Joe Biden   DEM
# 9             59               Florida        Broward County  Joe Biden   DEM
# ...          ...                   ...                   ...        ...   ...
# 3031       19525               Arizona           Pima County  Joe Biden   DEM
# 3033       19533               Arizona     Santa Cruz County  Joe Biden   DEM
# 3036       19545               Arizona         Apache County  Joe Biden   DEM
# 3038       19553               Arizona       Coconino County  Joe Biden   DEM
# 3043       19573               Arizona       Maricopa County  Joe Biden   DEM
#
# ...

# %%
df_dem.sort_values(['population'], ascending = False)
# Out:
#       Unnamed: 0         state              county  candidate party  \
# 2917       17826    California  Los Angeles County  Joe Biden   DEM
# 293         1632      Illinois         Cook County  Joe Biden   DEM
# 2261       14000         Texas       Harris County  Joe Biden   DEM
# 3043       19573       Arizona     Maricopa County  Joe Biden   DEM
# 2937       17948    California    San Diego County  Joe Biden   DEM
# ...          ...           ...                 ...        ...   ...
# 2007       12422  South Dakota      Buffalo County  Joe Biden   DEM
# 201         1064       Georgia   Taliaferro County  Joe Biden   DEM
# 1081        7351   Mississippi    Issaquena County  Joe Biden   DEM
# 2929       17900    California       Alpine County  Joe Biden   DEM
# 3016       19218      Colorado     San Juan County  Joe Biden   DEM
#
#       total_votes   won   fips state_code     male   female  median_age  \
# 2917      3028885  True   6037         CA  4976788  5121264        36.2
# ...

# %%
df_dem.sort_values(['population']).mean()
# Out:
# Unnamed: 0            10637.902893
# total_votes          111598.530992
# won                       1.000000
# fips                  29333.336777
# male                 183072.008264
# female               190595.070248
# median_age               37.890083
# population           373667.078512
# female_percentage        50.561422
# lat                      37.629334
# long                    -92.581405
# dtype: float64

# %%
#split dataframe 
grouped_rep = df.groupby(df.party) 
df_rep = grouped_rep.get_group("REP") 
df_rep
# Out:
#       Unnamed: 0     state           county     candidate party  total_votes  \
# 2              8  Delaware    Sussex County  Donald Trump   REP        71230
# 5             27   Florida     Baker County  Donald Trump   REP        11911
# 6             35   Florida       Bay County  Donald Trump   REP        66097
# 7             43   Florida  Bradford County  Donald Trump   REP        10334
# 8             51   Florida   Brevard County  Donald Trump   REP       207883
# ...          ...       ...              ...           ...   ...          ...
# 3039       19557   Arizona      Gila County  Donald Trump   REP        18377
# 3040       19561   Arizona    Graham County  Donald Trump   REP        10749
# 3041       19565   Arizona  Greenlee County  Donald Trump   REP         2433
# 3042       19569   Arizona    La Paz County  Donald Trump   REP         5129
# 3044       19577   Arizona    Mohave County  Donald Trump   REP        78535
#
# ...

# %%
df_rep.sort_values(['population'], ascending = True)
# Out:
#       Unnamed: 0       state            county     candidate party  \
# 2311       14210       Texas     Loving County  Donald Trump   REP
# 2295       14141       Texas       King County  Donald Trump   REP
# 1309        8799    Nebraska     Arthur County  Donald Trump   REP
# 1285        8704     Montana  Petroleum County  Donald Trump   REP
# 1365        9019    Nebraska  McPherson County  Donald Trump   REP
# ...          ...         ...               ...           ...   ...
# 2221       13832       Texas     Denton County  Donald Trump   REP
# 933         5973    Michigan     Macomb County  Donald Trump   REP
# 2913       17800  California       Kern County  Donald Trump   REP
# 2203       13753       Texas     Collin County  Donald Trump   REP
# 1522        9933    New York    Suffolk County  Donald Trump   REP
#
#       total_votes   won   fips state_code    male  female  median_age  \
# 2311           60  True  48301         TX      58      44        55.4
# ...

# %%
df_rep.sort_values(['population']).mean()
# Out:
# Unnamed: 0            9257.604061
# total_votes          15716.050761
# won                      1.000000
# fips                 30905.860601
# male                 24518.556814
# female               24891.772355
# median_age              41.904139
# population           49410.329168
# female_percentage       49.804216
# lat                     38.246022
# long                   -92.123438
# dtype: float64
